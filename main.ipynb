# %% [markdown]
# # Load environment and files

# %%
import numpy as np
import pandas as pd
import cv2
from ultralytics import YOLO
from perspective_transformer import PerspectiveTransformer
from creature_detector import CreatureDetector
from drawing import join_detections
from state_keeper import StateKeeper
import pickle

# %% [markdown]
# ## Load predictor model

# %%
model = YOLO('model/best.pt')

# %% [markdown]
# ## Load processing classes

# %%
transformer = PerspectiveTransformer()
detector = CreatureDetector(transformer)
state_keeper = StateKeeper()

# %% [markdown]
# ## Load video

# %%
video = cv2.VideoCapture("raw_videos/perro.mp4")

# %% [markdown]
# ## Set Parameters for output

# %%
fourcc = cv2.VideoWriter_fourcc(*"XVID")

out = cv2.VideoWriter(
        'output_videos/landmark.avi',
        fourcc,
        30,
        (848, 478),
)
n_frame = 0

# %%
# Loop through the video frames
while video.isOpened():
    # Read a frame from the video
    success, frame = video.read()
    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        detection = model.track(frame, persist=True, conf = 0.4, iou = 0.8, imgsz = 640, tracker = "bytetrack.yaml")[0]
        perro = join_detections(detection)
        distance = detector.get_creature_distance(perro)
        event = state_keeper.update(distance)
        cv2.rectangle(frame, (40,15), (550,95), (0,0,0), cv2.FILLED)
        cv2.putText(frame, f"La criatura se vio {state_keeper.hidden_state}: {state_keeper.count}", (50,40), cv2.FONT_HERSHEY_TRIPLEX, 0.6, (255,255,255), 1)
        cv2.putText(frame, f"La criatura esta {state_keeper.state}", (50,60), cv2.FONT_HERSHEY_TRIPLEX, 0.6, (255,255,255), 1)
        cv2.putText(frame, f"{event}", (50,80), cv2.FONT_HERSHEY_TRIPLEX, 0.6, (255,255,255), 1)
        annotated_frame = detector.draw_frame(frame,perro)
        out.write(annotated_frame)
    else:
        break
out.release()
# Out:
# 0: 384x640 1 item, 13.9ms
# Speed: 2.3ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.2ms
# Speed: 1.7ms preprocess, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 14.0ms
# Speed: 1.6ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.8ms
# Speed: 1.7ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item,
1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 1.7ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 1.8ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 1.7ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.3ms
# Speed: 1.5ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.3ms
# Speed: 2.1ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.1ms
# Speed: 2.1ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 1.9ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 14.3ms
# Speed: 1.6ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.5ms
# Speed: 1.6ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.2ms
# Speed: 1.7ms preprocess, 11.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.7ms
# Speed: 1.9ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 14.9ms
# Speed: 1.6ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 16.6ms
# Speed: 2.6ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 15.3ms
# Speed: 2.5ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.5ms
# Speed: 1.8ms preprocess, 12.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.9ms
# Speed: 2.0ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.4ms
# Speed: 1.9ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 item, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
